# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time
from tqdm import tqdm_notebook as tqdm
import requests as req

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://www.amazon.com/')
time.sleep(3)

# %%
search = driver.find_element_by_css_selector('#twotabsearchtextbox')

# %%
search.send_keys('coffee beans')
search.send_keys(Keys.ENTER)
time.sleep(3)

# %%
img = driver.find_elements_by_css_selector('img.s-image')

# %%
len(img)

# %%
len(score), len(review)

# %%
title = driver.find_elements_by_css_selector('#productTitle')
len(title)

# %%
for i in review_head:
    review_head = driver.find_elements_by_css_selector('a.a-size-base.a-link-normal.review-title.a-color-base.review-title-content.a-text-bold > span')
    review_head_list.append(i.text)

# %%
title = driver.find_element_by_css_selector('#productTitle')
title.text
product = title.text
product

# %%
for i in review_head:
    print(i.text)

# %%
review_head_list = []
review_list = []
title_list = []

for i in tqdm(range(2, 5)):
    img = driver.find_element_by_css_selector('#search > div.s-desktop-width-max.s-desktop-content.s-opposite-dir.sg-row > div.s-matching-dir.sg-col-16-of-20.sg-col.sg-col-8-of-12.sg-col-12-of-16 > div > span:nth-child(4) > div.s-main-slot.s-result-list.s-search-results.sg-row > div:nth-child({}) > div > div > div > div > div > div > div.s-product-image-container.aok-relative.s-image-overlay-grey.s-text-center.s-padding-left-small.s-padding-right-small.puis-spacing-small.s-height-equalized > span > a > div'.format(i))
    img.click()
    driver.implicitly_wait(2)

    title = driver.find_element_by_css_selector('#productTitle')
    product = title.text
    
    review_head = driver.find_elements_by_css_selector('div.a-profile-content > span')  
    for i in review_head:
        review_head_list.append(i.text)
    time.sleep(1)
    review = driver.find_elements_by_css_selector('div.a-expander-content.reviewText.review-text-content.a-expander-partial-collapse-content > span')
    for i in review:
        review_list.append(i.text)    
        time.sleep(1)
    for i in range(len(review)):
        title_list.append(product)
    driver.back()
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_18112\737069764.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(range(2, 5)):
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
review_head_list2 = []
for i in review_head_list:
    if i != "":
        review_head_list2.append(i)

# %%
data = {'제품명' : title_list,'리뷰작성자' : review_head_list2, '리뷰내용' : review_list}

# %%
amazon = pd.DataFrame(data)
amazon
# Out:
#                                                   제품명                  리뷰작성자  \
# 0   AmazonFresh Colombia Whole Bean Coffee, Medium...                  K. A.
# 1   AmazonFresh Colombia Whole Bean Coffee, Medium...  I Spend Too Much Here
# 2   AmazonFresh Colombia Whole Bean Coffee, Medium...          Deliza Nieves
# 3   AmazonFresh Colombia Whole Bean Coffee, Medium...                  Addie
# 4   AmazonFresh Colombia Whole Bean Coffee, Medium...            Kathy Smith
# 5   AmazonFresh Colombia Whole Bean Coffee, Medium...           Jason Harris
# 6   AmazonFresh Colombia Whole Bean Coffee, Medium...          Gerald Wilson
# 7   AmazonFresh Colombia Whole Bean Coffee, Medium...      City Girl "Carol"
# 8   The Mentalist Whole Bean Coffee, Medium Dark R...          Bronwyn Fargo
# 9   The Mentalist Whole Bean Coffee, Medium Dark R...      Christopher C Gay
# 10  The Mentalist Whole Bean Coffee, Medium Dark R...         Jeanie M. Wier
# 11  The Mentalist Whole Bean Coffee, Medium Dark R...      Linda K Steinberg
# 12  The Mentalist Whole Bean Coffee, Medium Dark R...        Kindle Customer
# 13  The Mentalist Whole Bean Coffee, Medium Dark R...                   L.B.
# 14  The Mentalist Whole Bean Coffee, Medium Dark R...        Amazon Customer
# 15  The Mentalist Whole Bean Coffee, Medium Dark R...                  J. A.
# 16  The Mentalist Whole Bean Coffee, Medium Dark R...              Baldvin B
# 17  The Mentalist Whole Bean Coffee, Medium Dark R...               Ahmed A.
# 18  The Mentalist Whole Bean Coffee, Medium Dark R...        Client d'Amazon
# 19  The Mentalist Whole Bean Coffee, Medium Dark R...        Amazon Customer
# 20  The Mentalist Whole Bean Coffee, Medium Dark R...        Amazon Customer
# 21  Coffee Bean Direct Decaf French Vanilla Flavor...    William D McClendon
# 22  Coffee Bean Direct Decaf French Vanilla Flavor...                 Schilo
# 23  Coffee Bean Direct Decaf French Vanilla Flavor...                   Lori
# 24  Coffee Bean Direct Decaf French Vanilla Flavor...                suefoxx
# 25  Coffee Bean Direct Decaf French Vanilla Flavor...       Chelsea Petersen
# 26  Coffee Bean Direct Decaf French Vanilla Flavor...            Susan Lewis
# 27  Coffee Bean Direct Decaf French Vanilla Flavor...     Robert J. Spangler
# 28  Coffee Bean Direct Decaf French Vanilla Flavor...                  big D
# 29  Coffee Bean Direct Decaf French Vanilla Flavor...            Rene Gendre
#
#                                                  리뷰내용
# 0   Like a lot of other reviewers, my usual coffee...
# 1   I think the only real draw to this is that it ...
# 2   I look forward to drinking coffee every mornin...
# 3   I've been buying eight o'clock Columbian roast...
# 4   When we compare these coffee beans with other ...
# 5   I'm normally a regular coffee guy, I've been g...
# 6   This is very flavorful delicious coffee, It's ...
# 7   My go to Costa Rica coffee beans made a big ju...
# 8   This coffee was recommended to me by my nutrit...
# 9   This is the best coffee I have had and even be...
# 10  Love this coffee and love thst it shows up at ...
# 11  At this point I've ordered about 100 bags of t...
# 12                        Great coffee and very fresh
# 13  I do love BP Coffee. However, this bag was har...
# 14  Taste was great easy on my stomach most coffee...
# 15  Fresh , and smooth flavored with perfect balan...
# 16  Whatever you are facing , whether it’s healing...
# 17  I usually drink Yemeni or Brazilian coffee whi...
# 18  Far, far, far too expensive for what it is, fl...
# 19  I received coffee that was out of date 3months...
# 20    I love this coffee but will source it elsewhere
# 21  We love this coffee. We used to be able to get...
# 22  Only negative is price, otherwise flavor/beans...
# 23  I used to buy this coffee in a small boutique....
# 24                            more than you shoud ask
# 25  Highlander Grogg is my favorite coffee. It bar...
# 26  I used to be a fan of hazelnut. Not anymore. B...
# 27       A favorite of mine A bit high but well worth
# 28  If you like flavored coffees or even if you do...
# 29  We have enjoyed this product for years - but w...

# %%
import nltk
from nltk import pos_tag
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt
import pickle
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\82104\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\82104\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\82104\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
review_list[0]
# Out:
# "Like a lot of other reviewers, my usual coffee had just gotten too expensive, so I decided to give Amazon a try. I bought the Columbia and the Donut Shop varieties. Both are pretty good. Not the best coffee I've ever had, but good flavor, especially considering the price. I think both taste better than Whole Foods 365 coffee (but not better than Whole Food's Allegro line), Target's in house brand, and Trader Joe's basic whole bean coffee.\n\nLike some others noted, it appears the roasting is inconsistent. The donut shop description indicates it's a medium-light roast and the Columbia is a medium roast, but the bag of donut shop I received was darker than the Columbia. If you're particular about your roast, this may not be the coffee for you. However, it's not a deal breaker for me, so I plan on purchasing again."

# %%
review_list_nltk = ''
for i in review_list:
    review_list_nltk = review_list_nltk + i

# %%
review_list_nltk
# Out:
# "Like a lot of other reviewers, my usual coffee had just gotten too expensive, so I decided to give Amazon a try. I bought the Columbia and the Donut Shop varieties. Both are pretty good. Not the best coffee I've ever had, but good flavor, especially considering the price. I think both taste better than Whole Foods 365 coffee (but not better than Whole Food's Allegro line), Target's in house brand, and Trader Joe's basic whole bean coffee.\n\nLike some others noted, it appears the roasting is inconsistent. The donut shop description indicates it's a medium-light roast and the Columbia is a medium roast, but the bag of donut shop I received was darker than the Columbia. If you're particular about your roast, this may not be the coffee for you. However, it's not a deal breaker for me, so I plan on purchasing again.I think the only real draw to this is that it is a 2LB bag for a fairly low price delivered to your door. This doesn't taste like a medium roast. Nor does it look it. More on the Dark for sure.\n\nFlavor is okay. Kind of a shock on my first cup coming from a Medium Roast from Intelligentsia. Was pretty dark tasting. The finish was bitter.\n\nI drink my coffee black. I like coffee to finish caramely and not too acidic. This was more on the burnt rubber side of flavor. But was probably exaggerated by my palate being used to the Intelligentsia coffee.\n\nI will finish off this bag (maybe). Then try a light roast from Amazon if they have one. Maybe the light roast will be a medium lol.I look forward to drinking coffee every morning. These beans are super fresh and my mornings so much better. Takes only a few seconds to grind and brew in my coffee maker. YummmmmI've been buying eight o'clock Columbian roast for quite a while and thought I'd dry Amazon's brand to compare and see if I could save a bit of money. This tastes every bit as good as what I was buying before so as long as it's the cheaper choice I'll continue getting this.When we compare these coffee beans with other brands, these beans are extremely flavorful.\nFor the price, these beans are one of the best purchases. We recommend these coffee beans.I'm normally a regular coffee guy, I've been grinding and brewing Dunkin Donuts whole bean for 10 plus years. I tried this as an inflation fighting measure and I don't regret it. It's a little darker than dunkin but tastes great! I am going to stick with this as long as the roast and flavor stays consistent. This is a winner.This is very flavorful delicious coffee, It's the full bean so you must have a grinder, but you get a fresh cup of coffee. if you enjoy Columbian coffee and don't want to have to drive to the big chained coffee place then you'll appreciate this coffee I will recommendMy go to Costa Rica coffee beans made a big jump in price and so I looked for another Medium Roast and saw this one by Amazon and thot what the heck let’s try a bag.\nI was pleasantly surprised when I smelled the beans. Very fresh and my first cup was very good. Will purchase again, thanks Amazon…This coffee was recommended to me by my nutritionist because they have a clean processing method, which is helpful for those of us who have a sensitivity to how coffee is processed. Works well for me!This is the best coffee I have had and even better when you mix the vanilla collagen in with it.Love this coffee and love thst it shows up at my door.At this point I've ordered about 100 bags of this coffee. My holistic doctor recommended it as a low mold coffee, for people with candida issues. We now drink it for the flavor. It's expensive, but fresh. I wish it were cheaper, but if the low mold claim is true, it's worth it to me. Flavor is great.Great coffee and very freshI do love BP Coffee. However, this bag was hard to use without a grinder and I was unable to Return. Which was a bit frustrating to pay this much for the coffee and not be able to speak to someone about the issue.Taste was great easy on my stomach most coffee I try has to much ac ...

# %%
nltk.corpus.stopwords.words('english')
stopwords = nltk.corpus.stopwords.words('english')

# %%
stopwords = ['i', 'be','see','lol.i','see','beans.i',
            'have','want','joe','look','bit','continue','winner.this',
            '”','t','bulletproof','say','“','do','me.i',]

# %%
def extract_tags_english(string):
    word_list = []
    string = string.lower()
    string = nltk.word_tokenize(string)
    string = nltk.pos_tag(string)
       
    for word, tag in string:
        if tag in ['NN', 'VB']:
            if word not in stopwords: #if word not in stopwords:
                word_list.append(word)

    return word_list

# %%
review_list_nltk_update = extract_tags_english(review_list_nltk)
review_list_nltk_update
# Out:
# ['lot',
#  'coffee',
#  'give',
#  'try',
#  'columbia',
#  'donut',
#  'shop',
#  'coffee',
#  'flavor',
#  'price',
#  'taste',
#  'coffee',
#  'food',
#  'line',
#  'target',
#  'house',
#  'brand',
#  'trader',
#  'bean',
#  'coffee',
#  'roasting',
#  'donut',
#  'shop',
#  'description',
#  'roast',
#  'columbia',
#  'medium',
#  'roast',
#  'bag',
#  'donut',
#  'shop',
#  'darker',
#  'columbia',
#  'roast',
#  'coffee',
#  'deal',
#  'breaker',
#  'plan',
#  'think',
#  'draw',
#  'bag',
#  'price',
#  'door',
#  'taste',
#  'medium',
#  'roast',
#  'dark',
#  'flavor',
#  'kind',
#  'shock',
#  'cup',
#  'medium',
#  'roast',
#  'intelligentsia',
#  'tasting',
#  'finish',
#  'coffee',
#  'coffee',
#  'finish',
#  'side',
#  'flavor',
#  'palate',
#  'coffee',
#  'finish',
#  'bag',
#  'try',
#  'roast',
#  'amazon',
#  'maybe',
#  'roast',
#  'medium',
#  'coffee',
#  'morning',
#  'grind',
#  'brew',
#  'coffee',
#  'maker',
#  'roast',
#  'while',
#  'dry',
#  'amazon',
#  'brand',
#  'compare',
#  'save',
#  'money',
#  'choice',
#  'coffee',
#  'price',
#  'coffee',
#  'coffee',
#  'guy',
#  'dunkin',
#  'bean',
#  'inflation',
#  'measure',
#  'regret',
#  'darker',
#  'stick',
#  'roast',
#  'flavor',
#  'consistent',
#  'coffee',
#  'bean',
#  'grinder',
#  'cup',
#  'coffee',
#  'coffee',
#  'drive',
#  'coffee',
#  'place',
#  'appreciate',
#  'coffee',
#  'recommendmy',
#  'go',
#  'costa',
#  'coffee',
#  'jump',
#  'price',
#  'medium',
#  'roast',
#  'amazon',
#  'thot',
#  'heck',
#  'let',
#  's',
#  'try',
#  'bag',
#  'cup',
#  'purchase',
#  'coffee',
#  'nutritionist',
#  'processing',
#  'method',
#  'sensitivity',
#  'coffee',
#  'coffee',
#  'vanilla',
#  'collagen',
#  'it.love',
#  'coffee',
#  'love',
#  'thst',
#  'door.at',
#  'point',
#  'coffee',
#  'doctor',
#  'mold',
#  'coffee',
#  'flavor',
#  'mold',
#  'claim',
#  'flavor',
#  'coffee',
#  'love',
#  'bp',
#  'coffee',
#  'bag',
#  'use',
#  'grinder',
#  'return',
#  'pay',
#  'coffee',
#  'speak',
#  'someone',
#  'issue.taste',
#  'stomach',
#  'coffee',
#  'try',
#  'acid',
#  'stomach',
#  'balance',
#  'get',
#  'blendwhatever',
#  'trauma',
#  'gut',
#  'depression',
#  'coffee',
#  'doubt',
#  'edge',
#  'focus',
#  'perform',
#  'ability',
#  'discard',
#  'stuff',
#  'mold',
#  'coffee',
#  'whatever',
#  'absence',
#  'side',
#  'coffee',
#  'life',
#  'mold',
#  'issue',
#  'increase',
#  'energy',
#  'function',
#  'energy',
#  'day',
#  'friend',
#  'try',
#  'drank',
#  'coffee',
#  'noon',
#  'while',
#  'reporting',
#  'focus',
#  'performance',
#  'marketing',
#  'job',
#  'coffee',
#  'oat',
#  'milk',
#  'hipster',
#  'coffee',
#  'shop',
#  'treat',
#  'humming',
#  'side',
#  'stuff',
#  'brain',
#  'octane',
#  'oil',
#  'grass',
#  'fed',
#  'ghee',
#  'coffee',
#  'coffee',
#  'buy',
#  'coffee',
#  'shop',
#  'fast',
#  'coffee',
#  'drink',
#  'toxin',
#  'form',
#  'coffee',
#  'verge',
#  'recommend',
#  'coffee',
#  'take',
#  'leap',
#  'faith',
#  'coffee',
#  'health',
#  'investment',
#  'coffee',
#  'style',
#  'try',
#  'coffee',
#  'result',
#  'book',
#  'find',
#  'downgrade',
#  'coffee',
#  'taste',
#  'book',
#  'don',
#  'recommendfar',
#  'organic',
#  'mildew',
#  'coffee',
#  'namei',
#  'coffee',
#  'date',
#  'sellotape',
#  'coffee',
#  'source',
#  'coffee',
#  'get',
#  'flavor',
#  'coffee',
#  'shop',
#  'surprise',
#  'find',
#  'coffee',
#  'smell',
#  'flavor',
#  'keep',
#  'price',
#  'future',
#  'buy',
#  'coffee',
#  'boutique',
#  'coffee',
#  'orange',
#  'peel',
#  'cup',
#  'coffee',
#  'grogg',
#  'coffee',
#  'creamer',
#  'flavor',
#  'fan',
#  'hazelnut',
#  'amazon',
#  'start',
#  'morning',
#  'right',
#  'd',
#  'favorite',
#  'mine',
#  'tasting',
#  'coffee',
#  'coffee',
#  'hint',
#  'coffee',
#  'flavor',
#  'coffee',
#  'taste',
#  'one',
#  'smack',
#  'face',
#  'sea',
#  'salt',
#  'caramel',
#  'mocha',
#  'keep',
#  'get',
#  'product',
#  'covid',
#  'coffee',
#  'bean',
#  'well',
#  'problem',
#  'amazon',
#  'coffee',
#  'heaven',
#  'coffee',
#  'bean',
#  'nothing']

# %%
count = Counter(review_list_nltk_update)
count
# Out:
# Counter({'lot': 1,
#          'coffee': 62,
#          'give': 1,
#          'try': 6,
#          'columbia': 3,
#          'donut': 3,
#          'shop': 6,
#          'flavor': 10,
#          'price': 5,
#          'taste': 4,
#          'food': 1,
#          'line': 1,
#          'target': 1,
#          'house': 1,
#          'brand': 2,
#          'trader': 1,
#          'bean': 5,
#          'roasting': 1,
#          'description': 1,
#          'roast': 10,
#          'medium': 5,
#          'bag': 5,
#          'darker': 2,
#          'deal': 1,
#          'breaker': 1,
#          'plan': 1,
#          'think': 1,
#          'draw': 1,
#          'door': 1,
#          'dark': 1,
#          'kind': 1,
#          'shock': 1,
#          'cup': 4,
#          'intelligentsia': 1,
#          'tasting': 2,
#          'finish': 3,
#          'side': 3,
#          'palate': 1,
#          'amazon': 5,
#          'maybe': 1,
#          'morning': 2,
#          'grind': 1,
#          'brew': 1,
#          'maker': 1,
#          'while': 2,
#          'dry': 1,
#          'compare': 1,
#          'save': 1,
#          'money': 1,
#          'choice': 1,
#          'guy': 1,
#          'dunkin': 1,
#          'inflation': 1,
#          'measure': 1,
#          'regret': 1,
#          'stick': 1,
#          'consistent': 1,
#          'grinder': 2,
#          'drive': 1,
#          'place': 1,
#          'appreciate': 1,
#          'recommendmy': 1,
#          'go': 1,
#          'costa': 1,
#          'jump': 1,
#          'thot': 1,
#          'heck': 1,
#          'let': 1,
#          's': 1,
#          'purchase': 1,
#          'nutritionist': 1,
#          'processing': 1,
#          'method': 1,
#          'sensitivity': 1,
#          'vanilla': 1,
#          'collagen': 1,
#          'it.love': 1,
#          'love': 2,
#          'thst': 1,
#          'door.at': 1,
#          'point': 1,
#          'doctor': 1,
#          'mold': 4,
#          'claim': 1,
#          'bp': 1,
#          'use': 1,
#          'return': 1,
#          'pay': 1,
#          'speak': 1,
#          'someone': 1,
#          'issue.taste': 1,
#          'stomach': 2,
#          'acid': 1,
#          'balance': 1,
#          'get': 3,
#          'blendwhatever': 1,
#          'trauma': 1,
#          'gut': 1,
#          'depression': 1,
#          'doubt': 1,
#          'edge': 1,
#          'focus': 2,
#          'perform': 1,
#          'ability': 1,
#          'discard': 1,
#          'stuff': 2,
#          'whatever': 1,
#          'absence': 1,
#          'life': 1,
#          'issue': 1,
#          'increase': 1,
#          'energy': 2,
#          'function': 1,
#          'day': 1,
#          'friend': 1,
#          'drank': 1,
#          'noon': 1,
#          'reporting': 1,
#          'performance': 1,
#          'marketing': 1,
#          'job': 1,
#          'oat': 1,
#          'milk': 1,
#          'hipster': 1,
#          'treat': 1,
#          'humming': 1,
#          'brain': 1,
#          'octane': 1,
#          'oil': 1,
#          'grass': 1,
#          'fed': 1,
#          'ghee': 1,
#          'buy': 2,
#          'fast': 1,
#          'drink': 1,
#          'toxin': 1,
#          'form': 1,
#          'verge': 1,
#          'recommend': 1,
#          'take': 1,
#          'leap': 1,
#          'faith': 1,
#          'health': 1,
#          'investment': 1,
#          'style': 1,
#          'result': 1,
#          'book': 2,
#          'find': 2,
#          'downgrade': 1,
#          'don': 1,
#          'recommendfar': 1,
#          'organic': 1,
#          'mildew': 1,
#          'namei': 1,
#          'date': 1,
#          'sellotape': 1,
#          'source': 1,
#          'surprise': 1,
#          'smell': 1,
#          'keep': 2,
#          'future': 1,
#          'boutique': 1,
#          'orange': 1,
#          'peel': 1,
#          'grogg': 1,
#          'creamer': 1,
#          'fan': 1,
#          'hazelnut': 1,
#          'start': 1,
#          'right': 1,
#          'd': 1,
#          'favorite': 1,
#          'mine': 1,
#          'hint': 1,
#          'one': 1,
#          'smack': 1,
#          'face': 1,
#          'sea': 1,
#          'salt': 1,
#          'caramel': 1,
#          'mocha': 1,
#          'product': 1,
#          'covid': 1,
#          'well': 1,
#          'problem': 1,
#          'heaven': 1,
#          'nothing': 1})

# %%
count.most_common(10)
# Out:
# [('coffee', 62),
#  ('flavor', 10),
#  ('roast', 10),
#  ('try', 6),
#  ('shop', 6),
#  ('price', 5),
#  ('bean', 5),
#  ('medium', 5),
#  ('bag', 5),
#  ('amazon', 5)]

# %%
from PIL import Image
import numpy as np

# %%
mask_image = np.array(Image.open(r'C:\Users\82104\Desktop\호랑이.jpg'))
mask_image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
wordcloud = WordCloud(font_path='C:\Windows\Fonts\gulim.ttc',
                     width = 700,height=700
                      ,background_color='black',colormap = 'summer'
                      ,mask = mask_image
                      ,random_state=1).generate_from_frequencies(count)

# %%
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.title("^-^", size = 30)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
