# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time
from tqdm import tqdm_notebook as tqdm
import requests as req

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
driver.get('https://lovinegar.com/entry/%EC%BB%A4%ED%94%BC-%EC%9B%90%EB%91%90%EC%9D%98-%EC%A2%85%EB%A5%98-%EC%BB%A4%ED%94%BC-%ED%9A%A8%EB%8A%A5%EA%B3%BC-%EB%82%B4-%EB%AA%B8%EC%97%90-%EB%A7%9E%EB%8A%94-%EC%BB%A4%ED%94%BC-%EC%84%AD%EC%B7%A8%EB%B2%95')

# %%
soup = bs(driver.page_source, 'html.parser')

# %%
title = driver.find_elements_by_css_selector('span > b')
#title.text
len(title)
# Out:
# 32

# %%
contents = driver.find_elements_by_css_selector('p > span')
#contents.text
len(contents)
# Out:
# 49

# %%
title_list = []
for i in title:
    title_list.append(i.text)

# %%
contents_list = []
for i in contents:
    contents_list.append(i.text)

# %%
data = {'제목' : title_list}

# %%
coffe = pd.DataFrame(data)
coffe
# Out:
#                                                    제목
# 0                                          ■ 원두커피 추천☕
# 1                                         - 커피 종류와 효능
# 2                                         ■ 커피 원두 종류☕
# 3                                                   ■
# 4
# 5                                                  생두
# 6                                              로스팅 작업
# 7                                              대표적으로
# 8   코페아 라비카(Coffea Arabica), 코페아 카네포라(Coffea Canep...
# 9                                               3대 원종
# 10                                   1. 아라비카(Arabica)
# 11                                        향미가 우수하고 신맛
# 12                 2. 로부스타(Robusta) = 카네포라(Canephora)
# 13                                        향미가 약하고 쓴 맛
# 14                                  3. 리베리카(Liberica)
# 15                                       향미가 떨어지고 쓴 맛
# 16                                   ■ 나라별 커피 원두 종류 ☕
# 17                                                 ■
# 18                                                 ■
# 19                                       자메이카 - 블루마운틴
# 20                                        콜롬비아 - 수프레모
# 21                                          하와이안 - 코나
# 22                                       에티오피아 - 예가체프
# 23                                            케냐 - AA
# 24                                          ■ 커피 효능 ☕
# 25                                                  ■
# 26                                                  ■
# 27                                         ■ 커피 부작용 ☕
# 28                                                 ■
# 29                                                 ■
# 30                                               수면장애
# 31                                    속이 자주 쓰리고 잦은 설사

# %%
data = {'내용' : contents_list}

# %%
coffe = pd.DataFrame(data)
coffe
# Out:
#                                                    내용
# 0             현대인들의 일상에서 빼놓을 수 없는 것 중에 하나가 바로 커피입니다.
# 1        혹시 커피숍에서 수없이 주문해서 마신 그 커피가 어떤 종류인지 알고 계시나요?
# 2             이제는 우리에게 '생명수'나 다름없는 커피 종류를 한번 알아보겠습니다.
# 3       커피나무에 열리는 커피 열매를 자연 건조 또는 습식법을 이용하여 생두로 만들고,
# 4             생두를 로스팅 기계에 돌려 로스팅 작업을 거치면 갈색 원두가 됩니다.
# 5                           커피의 종은 70여 가지가 있지만 대표적으로
# 6   코페아 라비카(Coffea Arabica), 코페아 카네포라(Coffea Canep...
# 7                              이렇게 3가지를 3대 원종이라고 합니다.
# 8            에티오피아가 원산지이며 전 세계 생산량의 70%가량을 차지하고 있습니다.
# 9        '고급 아라비카종(種)'이라는 말도 있을 만큼 고급 품종이라고 불리고 있으며,
# 10                              온도, 기후, 토양 병충해에 약합니다.
# 11        주요 생산국은 브라질, 콜롬비아, 과테말라, 케냐, 탄자니아 등이 있습니다.
# 12                                 향미가 우수하고 신맛이 좋습니다.
# 13                     콩고가 원산지이며, 고온다습한 저지대에서 재배합니다.
# 14                     병충해에 강하며 재배가 쉬워서 가격이 저렴한 편입니다.
# 15         주요 생산국은 베트남, 우간다, 인도, 카메룬, 인도네시아 등이 있습니다.
# 16                                 향미가 약하고 쓴 맛이 강합니다.
# 17      아프리카 리베리카가 원산지이며, 재배가 힘들고 과육이 두꺼워 가공이 어렵습니다.
# 18   품질 또한 로부스타에 비해 떨어지는 것으로 평가되어 자국에서 거의 소비되고 있습니다.
# 19                          아프리카, 동남아시아에서만 재배되고 있습니다.
# 20                       다른 종에 비해 향미가 떨어지고 쓴 맛이 강합니다.
# 21     세계 3대 커피 중 하나인 자메이카 블루마운틴 커피를 재배하는 블루 마운틴 커피는
# 22      자메이카에 있는 블루마운틴의 해발 900m ~ 1700m의 고지대에서 재배합니다.
# 23            산뜻하면서 묵직한 바디감, 단맛이 조화롭고 다양한 향의 밸런스가 좋아
# 24                                      마니아층이 두텁습니다.
# 25               생산량이 많지 않아 고가이며, 대부분 일본으로 수출되고 있습니다.
# 26                       콜롬비아 커피는 마일드 커피의 대명사라고 불리며,
# 27                                  대표적인 커피는 수프레모입니다.
# 28      브라질과 베트남에 이어 세계 3위의 커피 생산국으로 자국 내의 철저한 품질관리를
# 29              통과한 커피만을 출하하기 때문에 품질이 좋은 커피로도 유명합니다.
# 30  수프레모는 부드러운 신맛, 쓴맛, 단맛, 초콜릿 향이 조화로우며 풍부한 바디감이 특...
# 31                   하와이는 미국에서 유일하게 커피 재배가 가능한 지역이며,
# 32             코나 지역에서 생산되는 하와이안 코나는 자메이카 블루마운틴과 더불어
# 33                              세계 3대 커피 중 하나로 꼽힙니다.
# 34       상큼하고 고급스러운 신맛과 옅은 단맛, 부드러운 바디감이며 과일향이 풍부합니다.
# 35               에티오피아 남부 이르가체페(예가체프)에서 생산되는 고급 커피로,
# 36     부드러운 신맛과 과일향, 꽃향기를 가지고 있으며 '커피의 귀부인'이라고 불립니다.
# 37     예가체프는 에티오피아에서 생산되는 커피 중 품질이 가장 좋다고 평가받고 있습니다.
# 38                          2000~2500m의 고산지대에서 재배됩니다.
# 39                    케냐 수출품의 약 40%가량을 차지하는 케냐의 커피는,
# 40  세계적으로 커피시장 점유율이 0.5% 밖에 안 되지만, 엄격한 품질관리를 하고 있습...
# 41    국가 차원의 품질개발을 통해 아프리카를 대표하는 커피 생산국으로 인정받고 있습니다.
# 42   1500~2000m 고지대에서 생산되며, 묵직한 바디감과 농익은 과일향이 돋보입니다.
# 43           강한 산미가 매력적인 케냐산 원두는 여름철 아이스 메뉴에 많이 쓰입니다.
# 44            그럼 마지막으로 간단하게 커피 효능과 부작용에 대해 소개해드리겠습니다.
# 45             이렇게 많은 효능을 갖고 있는 커피는 몸에 좋은 효과를 가져오지만,
# 46                    체질에 맞지 않다면 반대로 부작용을 일으키기도 합니다.
# 47              수면장애를 갖고 있거나 속이 자주 쓰리고 잦은 설사를 하시는 분은
# 48     커피가 체질에 맞지 않을 수 있으니 다른 차를 커피보다는 마시는 것을 추천드립니다.
