# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('winter.csv', encoding='cp949')
df
# Out:
#       Year      City     Sport Discipline               Athlete Country  \
# 0     1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA
# 1     1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA
# 2     1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA
# 3     1924  Chamonix  Biathlon   Biathlon       VANDELLE, Andr챕     FRA
# 4     1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI
# ...    ...       ...       ...        ...                   ...     ...
# 5765  2014     Sochi    Skiing  Snowboard          JONES, Jenny     GBR
# 5766  2014     Sochi    Skiing  Snowboard       ANDERSON, Jamie     USA
# 5767  2014     Sochi    Skiing  Snowboard    MALTAIS, Dominique     CAN
# 5768  2014     Sochi    Skiing  Snowboard          SAMKOVA, Eva     CZE
# 5769  2014     Sochi    Skiing  Snowboard      TRESPEUCH, Chloe     FRA
#
#      Gender            Event   Medal
# 0       Men  Military Patrol  Bronze
# ...

# %%
#데이터에서 한국(KOR)데이터만 출력
kr = df[df.Country == 'KOR']
kr.head(3)
# Out:
#       Year         City    Sport                 Discipline       Athlete  \
# 2652  1992  Albertville  Skating  Short Track Speed Skating   LEE, Jun-Ho
# 2653  1992  Albertville  Skating  Short Track Speed Skating  KIM, Ki-Hoon
# 2671  1992  Albertville  Skating  Short Track Speed Skating  KIM, Ki-Hoon
#
#      Country Gender        Event   Medal
# 2652     KOR    Men        1000M  Bronze
# 2653     KOR    Men        1000M    Gold
# 2671     KOR    Men  5000M Relay    Gold

# %% [markdown]
# ##### pivot table

# %%
# 연도별 메달의 수는? -> 결측치 값을 0으로 채워넣기
# aggfunc = (' ') 안에 원하는 것 넣기(size, mean 같은것)
a = kr.pivot_table(index='Year',columns='Medal',aggfunc='size').fillna('0')
a
# Out:
# Medal Bronze  Gold  Silver
# Year
# 1992     1.0   5.0     1.0
# 1994     1.0   8.0     1.0
# 1998     2.0   6.0     4.0
# 2002       0   5.0     2.0
# 2006     2.0  14.0     3.0
# 2010     2.0   6.0    10.0
# 2014     2.0   7.0     5.0

# %%
#pivot table : Sport 별로 성별 수를 구해보기
b = kr.pivot_table(index="Sport", columns='Gender', aggfunc='size')#.fillna('0')
b
# Out:
# Gender   Men  Women
# Sport
# Skating   42     45

# %%
#pivot table : Discipline 별로 메달 수를 구해보기
c = kr.pivot_table(index='Discipline',columns='Medal',aggfunc='size')#.fillna('0')
c
# Out:
# Medal                      Bronze  Gold  Silver
# Discipline
# Figure skating                NaN   1.0     1.0
# Short Track Speed Skating     9.0  46.0    19.0
# Speed skating                 1.0   4.0     6.0
