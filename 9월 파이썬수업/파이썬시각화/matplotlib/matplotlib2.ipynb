# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname = 'C:/Windows/Fonts/malgun.ttf').get_name()
rc('font',family=font_name)

# %%
df = pd.read_csv('crime_in_Seoul.csv',encoding='euc-kr',index_col='관서명')
df.head(4)
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거
# 관서명
# 중부서       2      2      3      2    105     65  1,395   477  1,355  1,170
# 종로서       3      3      6      5    115     98  1,070   413  1,278  1,070
# 남대문서      1      0      6      4     65     46  1,153   382    869    794
# 서대문서      2      2      5      4    154    124  1,812   738  2,056  1,711

# %%
#상관관계 보기
df.corr()
# Out:
#           살인 발생     살인 검거     강도 발생     강도 검거     강간 발생     강간 검거
# 살인 발생  1.000000  0.953920  0.640281  0.486899  0.621728  0.572858
# 살인 검거  0.953920  1.000000  0.648964  0.505346  0.575409  0.571278
# 강도 발생  0.640281  0.648964  1.000000  0.866390  0.745120  0.798568
# 강도 검거  0.486899  0.505346  0.866390  1.000000  0.604698  0.744171
# 강간 발생  0.621728  0.575409  0.745120  0.604698  1.000000  0.915617
# 강간 검거  0.572858  0.571278  0.798568  0.744171  0.915617  1.000000

# %%
df[['살인 발생','살인 검거']].head(10)
# Out:
#       살인 발생  살인 검거
# 관서명
# 중부서       2      2
# 종로서       3      3
# 남대문서      1      0
# 서대문서      2      2
# 혜화서       3      2
# 용산서       5      5
# 성북서       2      2
# 동대문서      5      5
# 마포서       8      8
# 영등포서     14     12

# %%
df.plot(kind='scatter',x='살인 발생',y='살인 검거')
plt.show()

# %%
data1 = pd.read_csv('2014년 졸음운전 교통사고.csv',encoding='euc-kr')
data2 = pd.read_csv('2015년 졸음운전 교통사고.csv',encoding='euc-kr')
data3 = pd.read_csv('2016년 졸음운전 교통사고.csv',encoding='euc-kr')#,index_col='구분'

# %%
data = pd.concat([data1, data2,data3])
data.set_index('구분',inplace=True) #inplace=True 이상태로 저장하겠다는뜻
data
# Out:
#           사고(건)  사망(명)  부상(명)
# 구분
# 2014년1월     169      7    347
# 2014년2월     145      3    268
# 2014년3월     206     12    358
# 2014년4월     182      4    360
# 2014년5월     218     17    474
# 2014년6월     233     13    457
# 2014년7월     229     14    431
# 2014년8월     222      9    447
# 2014년9월     225     15    430
# 2014년10월    210     14    392
# 2014년11월    209     10    386
# 2014년12월    178     12    329
# 2015년1월     205      8    375
# 2015년2월     175      8    375
# 2015년3월     237      4    492
# 2015년4월     227     10    486
# 2015년5월     231      9    504
# 2015년6월     207      8    401
# 2015년7월     273      7    556
# 2015년8월     268     19    534
# 2015년9월     252     10    501
# 2015년10월    214     14    475
# 2015년11월    199      3    398
# 2015년12월    213      8    428
# 2016년1월     192      5    387
# 2016년2월     174      6    328
# 2016년3월     217      7    435
# 2016년4월     216      7    419
# 2016년5월     239     13    522
# 2016년6월     200     12    362
# ...

# %%
dt = data.copy() #복사
dt
# Out:
#           사고(건)  사망(명)  부상(명)
# 구분
# 2014년1월     169      7    347
# 2014년2월     145      3    268
# 2014년3월     206     12    358
# 2014년4월     182      4    360
# 2014년5월     218     17    474
# 2014년6월     233     13    457
# 2014년7월     229     14    431
# 2014년8월     222      9    447
# 2014년9월     225     15    430
# 2014년10월    210     14    392
# 2014년11월    209     10    386
# 2014년12월    178     12    329
# 2015년1월     205      8    375
# 2015년2월     175      8    375
# 2015년3월     237      4    492
# 2015년4월     227     10    486
# 2015년5월     231      9    504
# 2015년6월     207      8    401
# 2015년7월     273      7    556
# 2015년8월     268     19    534
# 2015년9월     252     10    501
# 2015년10월    214     14    475
# 2015년11월    199      3    398
# 2015년12월    213      8    428
# 2016년1월     192      5    387
# 2016년2월     174      6    328
# 2016년3월     217      7    435
# 2016년4월     216      7    419
# 2016년5월     239     13    522
# 2016년6월     200     12    362
# ...

# %%
dt.index = pd.to_datetime(dt.index,format='%Y년%m월')  #문자열로된날짜를
dt.set_index([dt.index.year,dt.index.month],inplace=True)
dt.index.names=['연도','월']
dt
# Out:
#          사고(건)  사망(명)  부상(명)
# 연도   월
# 2014 1     169      7    347
#      2     145      3    268
#      3     206     12    358
#      4     182      4    360
#      5     218     17    474
#      6     233     13    457
#      7     229     14    431
#      8     222      9    447
#      9     225     15    430
#      10    210     14    392
#      11    209     10    386
#      12    178     12    329
# 2015 1     205      8    375
#      2     175      8    375
#      3     237      4    492
#      4     227     10    486
#      5     231      9    504
#      6     207      8    401
#      7     273      7    556
#      8     268     19    534
#      9     252     10    501
#      10    214     14    475
#      11    199      3    398
#      12    213      8    428
# 2016 1     192      5    387
#      2     174      6    328
#      3     217      7    435
#      4     216      7    419
#      5     239     13    522
#      6     200     12    362
# ...

# %%
#연도별 평균 사망자
#월별 평균 사망자
#힌트 : groupby()

# %%
y = dt.groupby('연도').mean()[['사망(명)']]
y
# Out:
#           사망(명)
# 연도
# 2014  10.833333
# 2015   9.000000
# 2016   8.166667

# %%
m = dt.groupby('월').mean()[['사망(명)']]
m
# Out:
#         사망(명)
# 월
# 1    6.666667
# 2    5.666667
# 3    7.666667
# 4    7.000000
# 5   13.000000
# 6   11.000000
# 7   10.000000
# 8   11.666667
# 9   12.666667
# 10  12.666667
# 11   6.000000
# 12   8.000000

# %%
#2014년 월별 사망, 부상 데이터를 바 차트로 표현하기

# %%
dt.loc[2014][['사망(명)','부상(명)']].plot(kind='bar', rot=0)
plt.show()
