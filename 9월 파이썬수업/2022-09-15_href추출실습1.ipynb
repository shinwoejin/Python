# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time
from tqdm import tqdm_notebook as tqdm

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
driver.get('https://news.sbs.co.kr/news/newsflash.do?plink=NEW&cooper=SBSNEWSMAIN')

# %%
soup = bs(driver.page_source, 'html.parser')

# %%
search = soup.select('a.news')

# %%
for i in search:
    print('https://news.sbs.co.kr/'+i['href'])
# Out:
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896931
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897122
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897048
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896384
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897037
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897098
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897084
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897095
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897088
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897079

# %% [markdown]
# ### findall 사용

# %%
search2 = soup.find_all('a', class_='news')

# %%
for i in search2:
    print('https://news.sbs.co.kr/'+i['href'])
# Out:
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896931
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897122
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897048
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006896384
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897037
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897098
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897084
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897095
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897088
# https://news.sbs.co.kr//news/endPage.do?news_id=N1006897079

# %% [markdown]
# ### 기사 제목

# %%
#1~5페이지의 뉴스 상세 url 수집
url_list = []
for i in range(1,6):
    page_url = 'https://news.sbs.co.kr/news/newsflash.do?plink=NEW&cooper=SBSNEWSMAIN&pageIdx={}'.format(i)
    driver.get(page_url)
    time.sleep(1)
    soup = bs(driver.page_source, 'html.parser')
    search = soup.select('a.news')
    for i in search:
        url_list.append('https://news.sbs.co.kr/'+i['href'])

# %%
len(url_list)
# Out:
# 50

# %% [markdown]
# ### 상세페이지 내 기사 제목 & 내용

# %%
soup = bs(driver.page_source, 'html.parser')

# %%
title = soup.select('h2.blind.ir')
for i in title:
    print(i.text)

# %%
content = soup.select('div.text_area')
for i in content:
    print(i.text)

# %%
title_list = []
contents_list = []

for url in url_list:
    driver.get(url)
    time.sleep(1)
    soup = bs(driver.page_source, 'html.parser')
    #제목
    title = soup.select('h2.blind.ir')
    #for i in title:
    #title_list.append(i.text)
    title_list.append(title[0].text)
    
    #내용
    content = soup.select('div.text_area')
    #for i in content:
    #content_list.append(i.text)
    contents_list.append(content[0].text)

# %%
data = {'제목' : title_list, '내용' : contents_list, 'URL' : url_list}

# %%
news = pd.DataFrame(data)
news
# Out:
#                                                 제목  \
# 0                  레드카펫 위 '핑크 드레스'…'왕실 조롱' 태국인의 최후
# 1                      신종 마약 유통 · 투약한 태국인 등 27명 송치
# 2                      [자막뉴스] 김정은 옆 밀착 수행…새 얼굴의 정체
# 3              '라스트 찬스' 이강인, 실력으로 벤투 고집 꺾었다 [축덕쑥덕]
# 4              [자막뉴스] 여성 역무원 살해한 30대 남성…화장실까지 따라갔다
# 5                   조정훈 "특검은 핵폭탄" 박범계 "우리는 국민을 대변"
# 6                     양양 낙산에서 건물 진동…숙박업소 투숙객 대피 소동
# 7                        추석날 호텔서 마약 투약한 남녀 검찰에 넘겨져
# 8                '마약 투여' 유명 남성잡지 모델, 2심도 징역 8개월 실형
# 9            국민의힘 이용호, 원내대표 출마 선언 "외연 확장 상징 선택해달라"
# 10                  피겨 유영, 시즌 첫 국제 대회 쇼트 1위…김예림 5위
